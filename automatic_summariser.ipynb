# %% [markdown]
# <a href="https://colab.research.google.com/github/shaad0650/Taskify/blob/main/automatic_summariser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text=str(input('enter the text '))

# %%
len(text)

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation

# %%
nlp=spacy.load('en_core_web_sm')

# %%
doc=nlp(text)

# %%
tokens=[token.text.lower() for token in doc
        if not token.is_stop and
        not token.is_punct and
        token.text !='\n']

# %%
tokens
# Out:
# ['according',
#  'tech',
#  'jury',
#  'despite',
#  'number',
#  'cool',
#  'apps',
#  'tips',
#  'successful',
#  'time',
#  'management',
#  '17',
#  'people',
#  'track',
#  'time',
#  '50',
#  'people',
#  'thought',
#  'time',
#  'waste',
#  'late',
#  'running',
#  'time',
#  'time',
#  'management',
#  'skill',
#  'helps',
#  'people',
#  'handle',
#  'daily',
#  'duties',
#  'burnout',
#  'severe',
#  'exhaustion',
#  'n.i.l.c.',
#  'includes',
#  'time',
#  'management',
#  'list',
#  'demanded',
#  'soft',
#  'skills',
#  'employees',
#  'require',
#  '2022',
#  'important',
#  'manage',
#  'time',
#  'correctly',
#  'stephen',
#  'covey',
#  'said',
#  'key',
#  'spending',
#  'time',
#  'investing',
#  'means',
#  'proper',
#  'timing',
#  'guarantees',
#  'person',
#  'success',
#  'life',
#  'areas',
#  '\n\n',
#  'career',
#  'trend',
#  'names',
#  'negative',
#  'aspects',
#  'occur',
#  'person',
#  'able',
#  'follow',
#  'schedule',
#  'flexible',
#  'risks',
#  'delaying',
#  'task',
#  'performance',
#  'time',
#  'people',
#  'got',
#  'procrastination',
#  'start',
#  'assignments',
#  'duties',
#  'moment',
#  'result',
#  'sacrifice',
#  'quality',
#  'sake',
#  'deadlines',
#  'procrastination',
#  'perfect',
#  'killer',
#  'vital',
#  'energy',
#  'productiveness',
#  'essential',
#  'xxi',
#  'century',
#  'second',
#  'aspect',
#  'development',
#  'chronic',
#  'late',
#  'coming',
#  'habit',
#  'come',
#  'time',
#  'person',
#  'plan',
#  'activities',
#  'late',
#  'coming',
#  'procrastination',
#  'lead',
#  'negative',
#  'aspect',
#  'daily',
#  'overload',
#  'results',
#  'burnout',
#  'planned',
#  'people',
#  'busy',
#  'bed',
#  'late',
#  'relax',
#  'pressure',
#  'undone',
#  'tasks',
#  'prevents',
#  'normal',
#  'sleep',
#  'rest',
#  'result',
#  'acquire',
#  'panic',
#  'attacks',
#  'anxiety',
#  'sleep',
#  'disorders',
#  'apathy',
#  'depression',
#  '\n\n',
#  'mindtools',
#  'introduces',
#  'benefits',
#  'people',
#  'face',
#  'managing',
#  'day',
#  'successfully',
#  'begin',
#  'people',
#  'known',
#  'productive',
#  'effective',
#  'employers',
#  'adore',
#  'individuals',
#  'handle',
#  'tasks',
#  'faster',
#  'employees',
#  'secondly',
#  'ideal',
#  'time',
#  'managers',
#  'feel',
#  'stressed',
#  'work',
#  'know',
#  'time',
#  'require',
#  'scheduling',
#  'best',
#  'promoter',
#  'example',
#  'student',
#  'free',
#  'time',
#  'having',
#  'academic',
#  'homework',
#  'possible',
#  'broaden',
#  'look',
#  'student',
#  'read',
#  'books',
#  'enlarge',
#  'personal',
#  'vocabulary',
#  'practice',
#  'report',
#  'article',
#  'writing',
#  'visit',
#  'different',
#  'places',
#  'meet',
#  'new',
#  'people',
#  'networking',
#  'things',
#  'lead',
#  'benefit',
#  'positive',
#  'reputation',
#  'motivated',
#  'individuals',
#  'perfect',
#  'timing',
#  'skills',
#  'usually',
#  'model',
#  'following',
#  'finally',
#  'perfect',
#  'time',
#  'managers',
#  'chances',
#  'succeed',
#  'life',
#  'time',
#  'wasters',
#  'control',
#  'time',
#  'control',
#  'supervise',
#  '\n\n',
#  'person',
#  'learn',
#  'proper',
#  'scheduling',
#  'professionals',
#  'seven',
#  'tips',
#  'help',
#  'control',
#  'time',
#  'set',
#  'goals',
#  'motivation',
#  'ignition',
#  'key',
#  'goal',
#  'achievable',
#  'person',
#  'bad',
#  'geometry',
#  'creation',
#  'new',
#  'things',
#  'better',
#  'dream',
#  'designer',
#  'task',
#  'learn',
#  'prioritizing',
#  'concepts',
#  'people',
#  'tasks',
#  'later',
#  'delay',
#  'duties',
#  'right',
#  'neglect',
#  'tasks',
#  'long',
#  'perspective',
#  'example',
#  'person',
#  'needs',
#  'master',
#  'second',
#  'language',
#  'desired',
#  'occupation',
#  'tasks',
#  'forgets',
#  'memorize',
#  'new',
#  'words',
#  'practice',
#  'daily',
#  'result',
#  'job',
#  'language',
#  'mastering',
#  'demands',
#  'day',
#  'recommendation',
#  'set',
#  'time',
#  'frames',
#  'task',
#  'try',
#  'change',
#  'person',
#  'sees',
#  'approaching',
#  'deadline',
#  'speeds',
#  'bit',
#  'stops',
#  'delaying',
#  'duties',
#  'essential',
#  'thing',
#  'rest',
#  'brains',
#  'human',
#  'bodies',
#  'general',
#  'function',
#  'exhausted',
#  'everybody',
#  'knows',
#  '20',
#  'minutes',
#  'noon',
#  'sleep',
#  'restores',
#  'vital',
#  'energy',
#  'helps',
#  'handle',
#  'tasks',
#  'second',
#  'half',
#  'day',
#  'bedtime',
#  'needs',
#  'enjoy',
#  'hobby',
#  'pleasant',
#  'activity',
#  '\n\n',
#  'best',
#  'method',
#  'stay',
#  'alert',
#  'notebook',
#  'install',
#  'app',
#  'todoist',
#  'timetree',
#  'etc',
#  'benefit',
#  'notebook',
#  'person',
#  'deals',
#  'scheduling',
#  'jotting',
#  'distracted',
#  'messages',
#  'notifications',
#  'benefits',
#  'apps',
#  'notification',
#  'systems',
#  'compact',
#  'seizes',
#  'compatible',
#  'devices',
#  'forgets',
#  'smartphone',
#  'home',
#  'way',
#  '33',
#  'individuals',
#  'worldwide',
#  'use',
#  'todoist',
#  'handle',
#  'daily',
#  'duties',
#  'possible',
#  'use',
#  'wall',
#  'online',
#  'mobile',
#  'calendars',
#  'mark',
#  'important',
#  'meetings',
#  'tasks',
#  'system',
#  'send',
#  'reminders',
#  'person',
#  'forget',
#  'upcoming',
#  'event',
#  'finally',
#  'plan',
#  'advance',
#  'bad',
#  'idea',
#  'start',
#  'day',
#  'mess',
#  'head',
#  'psychologists',
#  'recommend',
#  'scheduling',
#  'evening',
#  'set',
#  'mind',
#  'morning',
#  '\n\n',
#  'extra',
#  'tip',
#  'beginners',
#  'sharing',
#  'duties',
#  'avoiding',
#  'extra',
#  'work',
#  'example',
#  'person',
#  'team',
#  'project',
#  'members',
#  'equal',
#  'responsibilities',
#  'guarantee',
#  'time',
#  'performance',
#  'friend',
#  'asks',
#  'exhausted',
#  'student',
#  'help',
#  'better',
#  'excuse',
#  'refuse',
#  'extra',
#  'tasks',
#  'friend',
#  'succeed',
#  'student',
#  'fail',
#  '\n\n',
#  'mentioned',
#  'facts',
#  'tips',
#  'highlight',
#  'importance',
#  'good',
#  'time',
#  'management',
#  'people',
#  'constantly',
#  'hurry',
#  'cope',
#  'tasks',
#  'feel',
#  'self',
#  'confident',
#  'afraid',
#  'coming',
#  'day',
#  'brings',
#  'responsibilities',
#  'duties',
#  'people',
#  'know',
#  'turn',
#  'minute',
#  'successful',
#  'life',
#  'investment',
#  'perfect',
#  'time',
#  'managers',
#  'lazy',
#  'productive',
#  'energy',
#  'leading',
#  'organizations',
#  'companies',
#  'desire',
#  'individuals',
#  'teams',
#  'boost',
#  'overall',
#  'productivity',
#  'proper',
#  'scheduling',
#  'lets',
#  'people',
#  'perfect',
#  'leaders',
#  'team',
#  'builders',
#  'assistants',
#  'performers',
#  'william',
#  'shakespear',
#  'said',
#  'better',
#  'hours',
#  'noon',
#  'minute',
#  'late']

# %%
tokens1=[]
stopwords=list(STOP_WORDS)
allowed_pos=['ADJ','PROPN','VERB','NOUN']
for token in doc:
    if token.text in stopwords or token.text in punctuation:
        continue
    if token.pos_ in allowed_pos:
        tokens1.append(token.text)

# %%
tokens1
# Out:
# ['According',
#  'Tech',
#  'Jury',
#  'number',
#  'cool',
#  'apps',
#  'tips',
#  'successful',
#  'time',
#  'management',
#  'people',
#  'track',
#  'time',
#  'people',
#  'thought',
#  'time',
#  'waste',
#  'late',
#  'running',
#  'time',
#  'Time',
#  'management',
#  'skill',
#  'helps',
#  'people',
#  'handle',
#  'daily',
#  'duties',
#  'burnout',
#  'severe',
#  'exhaustion',
#  'N.I.L.C.',
#  'includes',
#  'time',
#  'management',
#  'list',
#  'demanded',
#  'soft',
#  'skills',
#  'employees',
#  'require',
#  'important',
#  'manage',
#  'time',
#  'Stephen',
#  'Covey',
#  'said',
#  'key',
#  'spending',
#  'time',
#  'investing',
#  'means',
#  'proper',
#  'timing',
#  'guarantees',
#  'person',
#  'success',
#  'life',
#  'areas',
#  'Career',
#  'Trend',
#  'names',
#  'negative',
#  'aspects',
#  'occur',
#  'person',
#  'able',
#  'follow',
#  'schedule',
#  'flexible',
#  'risks',
#  'delaying',
#  'task',
#  'performance',
#  'time',
#  'People',
#  'procrastination',
#  'start',
#  'assignments',
#  'duties',
#  'moment',
#  'result',
#  'sacrifice',
#  'quality',
#  'sake',
#  'deadlines',
#  'procrastination',
#  'perfect',
#  'killer',
#  'vital',
#  'energy',
#  'productiveness',
#  'essential',
#  'XXI',
#  'century',
#  'second',
#  'aspect',
#  'development',
#  'chronic',
#  'coming',
#  'habit',
#  'come',
#  'time',
#  'person',
#  'plan',
#  'activities',
#  'coming',
#  'procrastination',
#  'lead',
#  'negative',
#  'aspect',
#  'daily',
#  'overload',
#  'results',
#  'burnout',
#  'planned',
#  'people',
#  'busy',
#  'bed',
#  'relax',
#  'pressure',
#  'undone',
#  'tasks',
#  'prevents',
#  'normal',
#  'sleep',
#  'rest',
#  'result',
#  'acquire',
#  'panic',
#  'attacks',
#  'anxiety',
#  'sleep',
#  'disorders',
#  'apathy',
#  'depression',
#  'Mindtools',
#  'introduces',
#  'benefits',
#  'people',
#  'face',
#  'managing',
#  'day',
#  'begin',
#  'people',
#  'known',
#  'productive',
#  'effective',
#  'Employers',
#  'adore',
#  'individuals',
#  'handle',
#  'tasks',
#  'employees',
#  'ideal',
#  'time',
#  'managers',
#  'feel',
#  'stressed',
#  'work',
#  'know',
#  'time',
#  'require',
#  'Third',
#  'scheduling',
#  'best',
#  'promoter',
#  'example',
#  'student',
#  'free',
#  'time',
#  'academic',
#  'homework',
#  'possible',
#  'broaden',
#  'look',
#  'student',
#  'read',
#  'books',
#  'enlarge',
#  'personal',
#  'vocabulary',
#  'practice',
#  'report',
#  'article',
#  'writing',
#  'visit',
#  'different',
#  'places',
#  'meet',
#  'new',
#  'people',
#  'networking',
#  'things',
#  'lead',
#  'benefit',
#  'positive',
#  'reputation',
#  'Motivated',
#  'individuals',
#  'perfect',
#  'timing',
#  'skills',
#  'model',
#  'following',
#  'perfect',
#  'time',
#  'managers',
#  'chances',
#  'succeed',
#  'life',
#  'time',
#  'wasters',
#  'control',
#  'time',
#  'control',
#  'supervise',
#  'person',
#  'learn',
#  'proper',
#  'scheduling',
#  'Professionals',
#  'tips',
#  'help',
#  'control',
#  'time',
#  'set',
#  'goals',
#  'Motivation',
#  'ignition',
#  'key',
#  'goal',
#  'achievable',
#  'person',
#  'bad',
#  'Geometry',
#  'creation',
#  'new',
#  'things',
#  'better',
#  'dream',
#  'designer',
#  'task',
#  'learn',
#  'prioritizing',
#  'concepts',
#  'People',
#  'tasks',
#  'delay',
#  'duties',
#  'neglect',
#  'tasks',
#  'long',
#  'perspective',
#  'example',
#  'person',
#  'needs',
#  'master',
#  'second',
#  'language',
#  'desired',
#  'occupation',
#  'tasks',
#  'forgets',
#  'memorize',
#  'new',
#  'words',
#  'practice',
#  'result',
#  'job',
#  'language',
#  'mastering',
#  'demands',
#  'day',
#  'recommendation',
#  'set',
#  'time',
#  'frames',
#  'task',
#  'try',
#  'change',
#  'person',
#  'sees',
#  'approaching',
#  'deadline',
#  'speeds',
#  'bit',
#  'stops',
#  'delaying',
#  'duties',
#  'essential',
#  'thing',
#  'rest',
#  'Brains',
#  'human',
#  'bodies',
#  'general',
#  'function',
#  'exhausted',
#  'knows',
#  'minutes',
#  'noon',
#  'sleep',
#  'restores',
#  'vital',
#  'energy',
#  'helps',
#  'handle',
#  'tasks',
#  'second',
#  'half',
#  'day',
#  'bedtime',
#  'needs',
#  'enjoy',
#  'hobby',
#  'pleasant',
#  'activity',
#  'best',
#  'method',
#  'stay',
#  'alert',
#  'notebook',
#  'install',
#  'app',
#  'Todoist',
#  'TimeTree',
#  'benefit',
#  'notebook',
#  'person',
#  'deals',
#  'scheduling',
#  'jotting',
#  'distracted',
#  'messages',
#  'notifications',
#  'benefits',
#  'apps',
#  'notification',
#  'systems',
#  'compact',
#  'seizes',
#  'compatible',
#  'devices',
#  'forgets',
#  'smartphone',
#  'home',
#  'way',
#  'individuals',
#  'use',
#  'Todoist',
#  'handle',
#  'daily',
#  'duties',
#  'possible',
#  'use',
#  'wall',
#  'online',
#  'mobile',
#  'calendars',
#  'mark',
#  'important',
#  'meetings',
#  'tasks',
#  'system',
#  'send',
#  'reminders',
#  'person',
#  'forget',
#  'upcoming',
#  'event',
#  'plan',
#  'advance',
#  'bad',
#  'idea',
#  'start',
#  'day',
#  'mess',
#  'head',
#  'Psychologists',
#  'recommend',
#  'scheduling',
#  'evening',
#  'set',
#  'mind',
#  'morning',
#  'extra',
#  'tip',
#  'beginners',
#  'sharing',
#  'duties',
#  'avoiding',
#  'extra',
#  'work',
#  'example',
#  'person',
#  'team',
#  'project',
#  'members',
#  'equal',
#  'responsibilities',
#  'guarantee',
#  'time',
#  'performance',
#  'friend',
#  'asks',
#  'exhausted',
#  'student',
#  'help',
#  'better',
#  'excuse',
#  'refuse',
#  'extra',
#  'tasks',
#  'friend',
#  'succeed',
#  'student',
#  'fail',
#  'mentioned',
#  'facts',
#  'tips',
#  'highlight',
#  'importance',
#  'good',
#  'time',
#  'management',
#  'people',
#  'hurry',
#  'cope',
#  'tasks',
#  'feel',
#  'self',
#  'confident',
#  'afraid',
#  'coming',
#  'day',
#  'brings',
#  'responsibilities',
#  'duties',
#  'Such',
#  'people',
#  'know',
#  'turn',
#  'minute',
#  'successful',
#  'life',
#  'investment',
#  'Perfect',
#  'time',
#  'managers',
#  'lazy',
#  'productive',
#  'energy',
#  'Leading',
#  'organizations',
#  'companies',
#  'desire',
#  'individuals',
#  'teams',
#  'boost',
#  'overall',
#  'productivity',
#  'Proper',
#  'scheduling',
#  'lets',
#  'people',
#  'perfect',
#  'leaders',
#  'team',
#  'builders',
#  'assistants',
#  'performers',
#  'William',
#  'Shakespear',
#  'said',
#  'Better',
#  'hours',
#  'noon',
#  'minute']

# %%
from collections import Counter

# %%
word_freq=Counter(tokens)

# %%
word_freq
# Out:
# Counter({'according': 1,
#          'tech': 1,
#          'jury': 1,
#          'despite': 1,
#          'number': 1,
#          'cool': 1,
#          'apps': 2,
#          'tips': 3,
#          'successful': 2,
#          'time': 21,
#          'management': 4,
#          '17': 1,
#          'people': 12,
#          'track': 1,
#          '50': 1,
#          'thought': 1,
#          'waste': 1,
#          'late': 5,
#          'running': 1,
#          'skill': 1,
#          'helps': 2,
#          'handle': 4,
#          'daily': 4,
#          'duties': 7,
#          'burnout': 2,
#          'severe': 1,
#          'exhaustion': 1,
#          'n.i.l.c.': 1,
#          'includes': 1,
#          'list': 1,
#          'demanded': 1,
#          'soft': 1,
#          'skills': 2,
#          'employees': 2,
#          'require': 2,
#          '2022': 1,
#          'important': 2,
#          'manage': 1,
#          'correctly': 1,
#          'stephen': 1,
#          'covey': 1,
#          'said': 2,
#          'key': 2,
#          'spending': 1,
#          'investing': 1,
#          'means': 1,
#          'proper': 3,
#          'timing': 2,
#          'guarantees': 1,
#          'person': 10,
#          'success': 1,
#          'life': 3,
#          'areas': 1,
#          '\n\n': 6,
#          'career': 1,
#          'trend': 1,
#          'names': 1,
#          'negative': 2,
#          'aspects': 1,
#          'occur': 1,
#          'able': 1,
#          'follow': 1,
#          'schedule': 1,
#          'flexible': 1,
#          'risks': 1,
#          'delaying': 2,
#          'task': 3,
#          'performance': 2,
#          'got': 1,
#          'procrastination': 3,
#          'start': 2,
#          'assignments': 1,
#          'moment': 1,
#          'result': 3,
#          'sacrifice': 1,
#          'quality': 1,
#          'sake': 1,
#          'deadlines': 1,
#          'perfect': 5,
#          'killer': 1,
#          'vital': 2,
#          'energy': 3,
#          'productiveness': 1,
#          'essential': 2,
#          'xxi': 1,
#          'century': 1,
#          'second': 3,
#          'aspect': 2,
#          'development': 1,
#          'chronic': 1,
#          'coming': 3,
#          'habit': 1,
#          'come': 1,
#          'plan': 2,
#          'activities': 1,
#          'lead': 2,
#          'overload': 1,
#          'results': 1,
#          'planned': 1,
#          'busy': 1,
#          'bed': 1,
#          'relax': 1,
#          'pressure': 1,
#          'undone': 1,
#          'tasks': 9,
#          'prevents': 1,
#          'normal': 1,
#          'sleep': 3,
#          'rest': 2,
#          'acquire': 1,
#          'panic': 1,
#          'attacks': 1,
#          'anxiety': 1,
#          'disorders': 1,
#          'apathy': 1,
#          'depression': 1,
#          'mindtools': 1,
#          'introduces': 1,
#          'benefits': 2,
#          'face': 1,
#          'managing': 1,
#          'day': 5,
#          'successfully': 1,
#          'begin': 1,
#          'known': 1,
#          'productive': 2,
#          'effective': 1,
#          'employers': 1,
#          'adore': 1,
#          'individuals': 4,
#          'faster': 1,
#          'secondly': 1,
#          'ideal': 1,
#          'managers': 3,
#          'feel': 2,
#          'stressed': 1,
#          'work': 2,
#          'know': 2,
#          'scheduling': 5,
#          'best': 2,
#          'promoter': 1,
#          'example': 3,
#          'student': 4,
#          'free': 1,
#          'having': 1,
#          'academic': 1,
#          'homework': 1,
#          'possible': 2,
#          'broaden': 1,
#          'look': 1,
#          'read': 1,
#          'books': 1,
#          'enlarge': 1,
#          'personal': 1,
#          'vocabulary': 1,
#          'practice': 2,
#          'report': 1,
#          'article': 1,
#          'writing': 1,
#          'visit': 1,
#          'different': 1,
#          'places': 1,
#          'meet': 1,
#          'new': 3,
#          'networking': 1,
#          'things': 2,
#          'benefit': 2,
#          'positive': 1,
#          'reputation': 1,
#          'motivated': 1,
#          'usually': 1,
#          'model': 1,
#          'following': 1,
#          'finally': 2,
#          'chances': 1,
#          'succeed': 2,
#          'wasters': 1,
#          'control': 3,
#          'supervise': 1,
#          'learn': 2,
#          'professionals': 1,
#          'seven': 1,
#          'help': 2,
#          'set': 3,
#          'goals': 1,
#          'motivation': 1,
#          'ignition': 1,
#          'goal': 1,
#          'achievable': 1,
#          'bad': 2,
#          'geometry': 1,
#          'creation': 1,
#          'better': 3,
#          'dream': 1,
#          'designer': 1,
#          'prioritizing': 1,
#          'concepts': 1,
#          'later': 1,
#          'delay': 1,
#          'right': 1,
#          'neglect': 1,
#          'long': 1,
#          'perspective': 1,
#          'needs': 2,
#          'master': 1,
#          'language': 2,
#          'desired': 1,
#          'occupation': 1,
#          'forgets': 2,
#          'memorize': 1,
#          'words': 1,
#          'job': 1,
#          'mastering': 1,
#          'demands': 1,
#          'recommendation': 1,
#          'frames': 1,
#          'try': 1,
#          'change': 1,
#          'sees': 1,
#          'approaching': 1,
#          'deadline': 1,
#          'speeds': 1,
#          'bit': 1,
#          'stops': 1,
#          'thing': 1,
#          'brains': 1,
#          'human': 1,
#          'bodies': 1,
#          'general': 1,
#          'function': 1,
#          'exhausted': 2,
#          'everybody': 1,
#          'knows': 1,
#          '20': 1,
#          'minutes': 1,
#          'noon': 2,
#          'restores': 1,
#          'half': 1,
#          'bedtime': 1,
#          'enjoy': 1,
#          'hobby': 1,
#          'pleasant': 1,
#          'activity': 1,
#          'method': 1,
#          'stay': 1,
#          'alert': 1,
#          'notebook': 2,
#          'install': 1,
#          'app': 1,
#          'todoist': 2,
#          'timetree': 1,
#          'etc': 1,
#          'deals': 1,
#          'jotting': 1,
#          'distracted': 1,
#          'messages': 1,
#          'notifications': 1,
#          'notification': 1,
#          'systems': 1,
#          'compact': 1,
#          'seizes': 1,
#          'compatible': 1,
#          'devices': 1,
#          'smartphone': 1,
#          'home': 1,
#          'way': 1,
#          '33': 1,
#          'worldwide': 1,
#          'use': 2,
#          'wall': 1,
#          'online': 1,
#          'mobile': 1,
#          'calendars': 1,
#          'mark': 1,
#          'meetings': 1,
#          'system': 1,
#          'send': 1,
#          'reminders': 1,
#          'forget': 1,
#          'upcoming': 1,
#          'event': 1,
#          'advance': 1,
#          'idea': 1,
#          'mess': 1,
#          'head': 1,
#          'psychologists': 1,
#          'recommend': 1,
#          'evening': 1,
#          'mind': 1,
#          'morning': 1,
#          'extra': 3,
#          'tip': 1,
#          'beginners': 1,
#          'sharing': 1,
#          'avoiding': 1,
#          'team': 2,
#          'project': 1,
#          'members': 1,
#          'equal': 1,
#          'responsibilities': 2,
#          'guarantee': 1,
#          'friend': 2,
#          'asks': 1,
#          'excuse': 1,
#          'refuse': 1,
#          'fail': 1,
#          'mentioned': 1,
#          'facts': 1,
#          'highlight': 1,
#          'importance': 1,
#          'good': 1,
#          'constantly': 1,
#          'hurry': 1,
#          'cope': 1,
#          'self': 1,
#          'confident': 1,
#          'afraid': 1,
#          'brings': 1,
#          'turn': 1,
#          'minute': 2,
#          'investment': 1,
#          'lazy': 1,
#          'leading': 1,
#          'organizations': 1,
#          'companies': 1,
#          'desire': 1,
#          'teams': 1,
#          'boost': 1,
#          'overall': 1,
#          'productivity': 1,
#          'lets': 1,
#          'leaders': 1,
#          'builders': 1,
#          'assistants': 1,
#          'performers': 1,
#          'william': 1,
#          'shakespear': 1,
#          'hours': 1})

# %%
max_freq=max(word_freq.values())

# %%
max_freq
# Out:
# 21

# %%
for word in word_freq.keys():
    word_freq[word]=word_freq[word]/max_freq

# %%
word_freq
# Out:
# Counter({'according': 0.047619047619047616,
#          'tech': 0.047619047619047616,
#          'jury': 0.047619047619047616,
#          'despite': 0.047619047619047616,
#          'number': 0.047619047619047616,
#          'cool': 0.047619047619047616,
#          'apps': 0.09523809523809523,
#          'tips': 0.14285714285714285,
#          'successful': 0.09523809523809523,
#          'time': 1.0,
#          'management': 0.19047619047619047,
#          '17': 0.047619047619047616,
#          'people': 0.5714285714285714,
#          'track': 0.047619047619047616,
#          '50': 0.047619047619047616,
#          'thought': 0.047619047619047616,
#          'waste': 0.047619047619047616,
#          'late': 0.23809523809523808,
#          'running': 0.047619047619047616,
#          'skill': 0.047619047619047616,
#          'helps': 0.09523809523809523,
#          'handle': 0.19047619047619047,
#          'daily': 0.19047619047619047,
#          'duties': 0.3333333333333333,
#          'burnout': 0.09523809523809523,
#          'severe': 0.047619047619047616,
#          'exhaustion': 0.047619047619047616,
#          'n.i.l.c.': 0.047619047619047616,
#          'includes': 0.047619047619047616,
#          'list': 0.047619047619047616,
#          'demanded': 0.047619047619047616,
#          'soft': 0.047619047619047616,
#          'skills': 0.09523809523809523,
#          'employees': 0.09523809523809523,
#          'require': 0.09523809523809523,
#          '2022': 0.047619047619047616,
#          'important': 0.09523809523809523,
#          'manage': 0.047619047619047616,
#          'correctly': 0.047619047619047616,
#          'stephen': 0.047619047619047616,
#          'covey': 0.047619047619047616,
#          'said': 0.09523809523809523,
#          'key': 0.09523809523809523,
#          'spending': 0.047619047619047616,
#          'investing': 0.047619047619047616,
#          'means': 0.047619047619047616,
#          'proper': 0.14285714285714285,
#          'timing': 0.09523809523809523,
#          'guarantees': 0.047619047619047616,
#          'person': 0.47619047619047616,
#          'success': 0.047619047619047616,
#          'life': 0.14285714285714285,
#          'areas': 0.047619047619047616,
#          '\n\n': 0.2857142857142857,
#          'career': 0.047619047619047616,
#          'trend': 0.047619047619047616,
#          'names': 0.047619047619047616,
#          'negative': 0.09523809523809523,
#          'aspects': 0.047619047619047616,
#          'occur': 0.047619047619047616,
#          'able': 0.047619047619047616,
#          'follow': 0.047619047619047616,
#          'schedule': 0.047619047619047616,
#          'flexible': 0.047619047619047616,
#          'risks': 0.047619047619047616,
#          'delaying': 0.09523809523809523,
#          'task': 0.14285714285714285,
#          'performance': 0.09523809523809523,
#          'got': 0.047619047619047616,
#          'procrastination': 0.14285714285714285,
#          'start': 0.09523809523809523,
#          'assignments': 0.047619047619047616,
#          'moment': 0.047619047619047616,
#          'result': 0.14285714285714285,
#          'sacrifice': 0.047619047619047616,
#          'quality': 0.047619047619047616,
#          'sake': 0.047619047619047616,
#          'deadlines': 0.047619047619047616,
#          'perfect': 0.23809523809523808,
#          'killer': 0.047619047619047616,
#          'vital': 0.09523809523809523,
#          'energy': 0.14285714285714285,
#          'productiveness': 0.047619047619047616,
#          'essential': 0.09523809523809523,
#          'xxi': 0.047619047619047616,
#          'century': 0.047619047619047616,
#          'second': 0.14285714285714285,
#          'aspect': 0.09523809523809523,
#          'development': 0.047619047619047616,
#          'chronic': 0.047619047619047616,
#          'coming': 0.14285714285714285,
#          'habit': 0.047619047619047616,
#          'come': 0.047619047619047616,
#          'plan': 0.09523809523809523,
#          'activities': 0.047619047619047616,
#          'lead': 0.09523809523809523,
#          'overload': 0.047619047619047616,
#          'results': 0.047619047619047616,
#          'planned': 0.047619047619047616,
#          'busy': 0.047619047619047616,
#          'bed': 0.047619047619047616,
#          'relax': 0.047619047619047616,
#          'pressure': 0.047619047619047616,
#          'undone': 0.047619047619047616,
#          'tasks': 0.42857142857142855,
#          'prevents': 0.047619047619047616,
#          'normal': 0.047619047619047616,
#          'sleep': 0.14285714285714285,
#          'rest': 0.09523809523809523,
#          'acquire': 0.047619047619047616,
#          'panic': 0.047619047619047616,
#          'attacks': 0.047619047619047616,
#          'anxiety': 0.047619047619047616,
#          'disorders': 0.047619047619047616,
#          'apathy': 0.047619047619047616,
#          'depression': 0.047619047619047616,
#          'mindtools': 0.047619047619047616,
#          'introduces': 0.047619047619047616,
#          'benefits': 0.09523809523809523,
#          'face': 0.047619047619047616,
#          'managing': 0.047619047619047616,
#          'day': 0.23809523809523808,
#          'successfully': 0.047619047619047616,
#          'begin': 0.047619047619047616,
#          'known': 0.047619047619047616,
#          'productive': 0.09523809523809523,
#          'effective': 0.047619047619047616,
#          'employers': 0.047619047619047616,
#          'adore': 0.047619047619047616,
#          'individuals': 0.19047619047619047,
#          'faster': 0.047619047619047616,
#          'secondly': 0.047619047619047616,
#          'ideal': 0.047619047619047616,
#          'managers': 0.14285714285714285,
#          'feel': 0.09523809523809523,
#          'stressed': 0.047619047619047616,
#          'work': 0.09523809523809523,
#          'know': 0.09523809523809523,
#          'scheduling': 0.23809523809523808,
#          'best': 0.09523809523809523,
#          'promoter': 0.047619047619047616,
#          'example': 0.14285714285714285,
#          'student': 0.19047619047619047,
#          'free': 0.047619047619047616,
#          'having': 0.047619047619047616,
#          'academic': 0.047619047619047616,
#          'homework': 0.047619047619047616,
#          'possible': 0.09523809523809523,
#          'broaden': 0.047619047619047616,
#          'look': 0.047619047619047616,
#          'read': 0.047619047619047616,
#          'books': 0.047619047619047616,
#          'enlarge': 0.047619047619047616,
#          'personal': 0.047619047619047616,
#          'vocabulary': 0.047619047619047616,
#          'practice': 0.09523809523809523,
#          'report': 0.047619047619047616,
#          'article': 0.047619047619047616,
#          'writing': 0.047619047619047616,
#          'visit': 0.047619047619047616,
#          'different': 0.047619047619047616,
#          'places': 0.047619047619047616,
#          'meet': 0.047619047619047616,
#          'new': 0.14285714285714285,
#          'networking': 0.047619047619047616,
#          'things': 0.09523809523809523,
#          'benefit': 0.09523809523809523,
#          'positive': 0.047619047619047616,
#          'reputation': 0.047619047619047616,
#          'motivated': 0.047619047619047616,
#          'usually': 0.047619047619047616,
#          'model': 0.047619047619047616,
#          'following': 0.047619047619047616,
#          'finally': 0.09523809523809523,
#          'chances': 0.047619047619047616,
#          'succeed': 0.09523809523809523,
#          'wasters': 0.047619047619047616,
#          'control': 0.14285714285714285,
#          'supervise': 0.047619047619047616,
#          'learn': 0.09523809523809523,
#          'professionals': 0.047619047619047616,
#          'seven': 0.047619047619047616,
#          'help': 0.09523809523809523,
#          'set': 0.14285714285714285,
#          'goals': 0.047619047619047616,
#          'motivation': 0.047619047619047616,
#          'ignition': 0.047619047619047616,
#          'goal': 0.047619047619047616,
#          'achievable': 0.047619047619047616,
#          'bad': 0.09523809523809523,
#          'geometry': 0.047619047619047616,
#          'creation': 0.047619047619047616,
#          'better': 0.14285714285714285,
#          'dream': 0.047619047619047616,
#          'designer': 0.047619047619047616,
#          'prioritizing': 0.047619047619047616,
#          'concepts': 0.047619047619047616,
#          'later': 0.047619047619047616,
#          'delay': 0.047619047619047616,
#          'right': 0.047619047619047616,
#          'neglect': 0.047619047619047616,
#          'long': 0.047619047619047616,
#          'perspective': 0.047619047619047616,
#          'needs': 0.09523809523809523,
#          'master': 0.047619047619047616,
#          'language': 0.09523809523809523,
#          'desired': 0.047619047619047616,
#          'occupation': 0.047619047619047616,
#          'forgets': 0.09523809523809523,
#          'memorize': 0.047619047619047616,
#          'words': 0.047619047619047616,
#          'job': 0.047619047619047616,
#          'mastering': 0.047619047619047616,
#          'demands': 0.047619047619047616,
#          'recommendation': 0.047619047619047616,
#          'frames': 0.047619047619047616,
#          'try': 0.047619047619047616,
#          'change': 0.047619047619047616,
#          'sees': 0.047619047619047616,
#          'approaching': 0.047619047619047616,
#          'deadline': 0.047619047619047616,
#          'speeds': 0.047619047619047616,
#          'bit': 0.047619047619047616,
#          'stops': 0.047619047619047616,
#          'thing': 0.047619047619047616,
#          'brains': 0.047619047619047616,
#          'human': 0.047619047619047616,
#          'bodies': 0.047619047619047616,
#          'general': 0.047619047619047616,
#          'function': 0.047619047619047616,
#          'exhausted': 0.09523809523809523,
#          'everybody': 0.047619047619047616,
#          'knows': 0.047619047619047616,
#          '20': 0.047619047619047616,
#          'minutes': 0.047619047619047616,
#          'noon': 0.09523809523809523,
#          'restores': 0.047619047619047616,
#          'half': 0.047619047619047616,
#          'bedtime': 0.047619047619047616,
#          'enjoy': 0.047619047619047616,
#          'hobby': 0.047619047619047616,
#          'pleasant': 0.047619047619047616,
#          'activity': 0.047619047619047616,
#          'method': 0.047619047619047616,
#          'stay': 0.047619047619047616,
#          'alert': 0.047619047619047616,
#          'notebook': 0.09523809523809523,
#          'install': 0.047619047619047616,
#          'app': 0.047619047619047616,
#          'todoist': 0.09523809523809523,
#          'timetree': 0.047619047619047616,
#          'etc': 0.047619047619047616,
#          'deals': 0.047619047619047616,
#          'jotting': 0.047619047619047616,
#          'distracted': 0.047619047619047616,
#          'messages': 0.047619047619047616,
#          'notifications': 0.047619047619047616,
#          'notification': 0.047619047619047616,
#          'systems': 0.047619047619047616,
#          'compact': 0.047619047619047616,
#          'seizes': 0.047619047619047616,
#          'compatible': 0.047619047619047616,
#          'devices': 0.047619047619047616,
#          'smartphone': 0.047619047619047616,
#          'home': 0.047619047619047616,
#          'way': 0.047619047619047616,
#          '33': 0.047619047619047616,
#          'worldwide': 0.047619047619047616,
#          'use': 0.09523809523809523,
#          'wall': 0.047619047619047616,
#          'online': 0.047619047619047616,
#          'mobile': 0.047619047619047616,
#          'calendars': 0.047619047619047616,
#          'mark': 0.047619047619047616,
#          'meetings': 0.047619047619047616,
#          'system': 0.047619047619047616,
#          'send': 0.047619047619047616,
#          'reminders': 0.047619047619047616,
#          'forget': 0.047619047619047616,
#          'upcoming': 0.047619047619047616,
#          'event': 0.047619047619047616,
#          'advance': 0.047619047619047616,
#          'idea': 0.047619047619047616,
#          'mess': 0.047619047619047616,
#          'head': 0.047619047619047616,
#          'psychologists': 0.047619047619047616,
#          'recommend': 0.047619047619047616,
#          'evening': 0.047619047619047616,
#          'mind': 0.047619047619047616,
#          'morning': 0.047619047619047616,
#          'extra': 0.14285714285714285,
#          'tip': 0.047619047619047616,
#          'beginners': 0.047619047619047616,
#          'sharing': 0.047619047619047616,
#          'avoiding': 0.047619047619047616,
#          'team': 0.09523809523809523,
#          'project': 0.047619047619047616,
#          'members': 0.047619047619047616,
#          'equal': 0.047619047619047616,
#          'responsibilities': 0.09523809523809523,
#          'guarantee': 0.047619047619047616,
#          'friend': 0.09523809523809523,
#          'asks': 0.047619047619047616,
#          'excuse': 0.047619047619047616,
#          'refuse': 0.047619047619047616,
#          'fail': 0.047619047619047616,
#          'mentioned': 0.047619047619047616,
#          'facts': 0.047619047619047616,
#          'highlight': 0.047619047619047616,
#          'importance': 0.047619047619047616,
#          'good': 0.047619047619047616,
#          'constantly': 0.047619047619047616,
#          'hurry': 0.047619047619047616,
#          'cope': 0.047619047619047616,
#          'self': 0.047619047619047616,
#          'confident': 0.047619047619047616,
#          'afraid': 0.047619047619047616,
#          'brings': 0.047619047619047616,
#          'turn': 0.047619047619047616,
#          'minute': 0.09523809523809523,
#          'investment': 0.047619047619047616,
#          'lazy': 0.047619047619047616,
#          'leading': 0.047619047619047616,
#          'organizations': 0.047619047619047616,
#          'companies': 0.047619047619047616,
#          'desire': 0.047619047619047616,
#          'teams': 0.047619047619047616,
#          'boost': 0.047619047619047616,
#          'overall': 0.047619047619047616,
#          'productivity': 0.047619047619047616,
#          'lets': 0.047619047619047616,
#          'leaders': 0.047619047619047616,
#          'builders': 0.047619047619047616,
#          'assistants': 0.047619047619047616,
#          'performers': 0.047619047619047616,
#          'william': 0.047619047619047616,
#          'shakespear': 0.047619047619047616,
#          'hours': 0.047619047619047616})

# %%
sent_token=[sent.text for sent in doc.sents]

# %%
sent_token
# Out:
# ['According to Tech Jury, despite a number of cool apps and tips for successful time management, only 17% of people track their time.',
#  '50% of people have never thought about time waste, even though they are always late and running out of time.',
#  'Time management is a skill.',
#  'It helps people handle their daily duties without burnout and severe exhaustion.',
#  'The N.I.L.C. includes time management on the list of top ten demanded soft skills that employees require in 2022.',
#  'Why is it so important to manage one’s time correctly?',
#  'Stephen Covey once said, “The key is not spending time, but in investing it”.',
#  'It means that proper timing guarantees a person’s success in many life areas.\n\n',
#  'Career Trend names three negative aspects that occur when a person is not able to follow a schedule and be flexible.',
#  'First off, one risks delaying the task performance all the time.',
#  'People who got used to procrastination start doing assignments and duties at the very last moment.',
#  'As a result, they sacrifice quality for the sake of deadlines.',
#  'Moreover, procrastination is a perfect killer of vital energy and productiveness that are so essential in the XXI century.',
#  'The second aspect is the development of a chronic late-coming habit.',
#  'How can one come somewhere on time if a person cannot plan activities?',
#  'Besides, late-coming and procrastination lead to the third negative aspect.',
#  'It is a daily overload that results in burnout.',
#  'When nothing is well-planned, people always get busy with something, go to bed late, and cannot relax.',
#  'The pressure of undone tasks prevents them from normal sleep and rest.',
#  'As a result, they acquire panic attacks, anxiety, sleep disorders, apathy, or depression.\n\n',
#  'Mindtools introduces five benefits that people face when managing their day successfully.',
#  'To begin with, such people are known as productive and effective in what they do.',
#  'Employers adore such individuals because they handle many tasks faster than other employees.',
#  'Secondly, ideal time managers almost never feel stressed at work.',
#  'They know what they have to do and how much time they require for that.',
#  'Third, scheduling is the best promoter.',
#  'For example, if a student has free time after having done academic homework, it will be possible to broaden one’s look.',
#  'Such a student can read books to enlarge personal vocabulary, practice in report or article writing, visit different places, and meet new people for networking.',
#  'All these things lead to the next benefit which is a positive reputation.',
#  'Motivated individuals with perfect timing skills usually become a model for following.',
#  'Finally, perfect time managers have more chances to succeed in life than time wasters.',
#  'Those who control their time can control and supervise others.\n\n',
#  'What can a person do to learn proper scheduling?',
#  'Professionals give seven tips that can help everyone get more control over time.',
#  'The first one is to set goals.',
#  'Motivation is an ignition key.',
#  'Moreover, the goal is to be achievable.',
#  'If a person is bad at Geometry and the creation of new things, it is better not to dream about becoming a top designer.',
#  'The next task is to learn prioritizing concepts.',
#  'People often do tasks that can be done later but delay duties that should be done here and right now.',
#  'Moreover, they often neglect tasks that are long-perspective.',
#  'For example, a person needs to master a second language to get the desired occupation.',
#  'She does other tasks but forgets to memorize new words and practice daily.',
#  'As a result, she will not get the job because language mastering demands more than one day.',
#  'The next recommendation is to set time frames for each task and try not to change them.',
#  'When a person sees the approaching deadline, he speeds up a bit and stops delaying duties.',
#  'Another essential thing is to have rest.',
#  'Brains and human bodies, in general, cannot function well when being exhausted.',
#  'Everybody knows that 20 minutes of noon sleep restores vital energy that helps to handle tasks in the second half of the day.',
#  'Except for bedtime, one needs to enjoy a hobby or a pleasant activity.\n\n',
#  'The best method to stay on alert is to have a notebook or install an app such as Todoist, TimeTree, etc.',
#  'A benefit of a notebook is that a person deals only with scheduling and jotting down without being distracted by messages and notifications.',
#  'The benefits of apps are their notification systems and compact seizes of compatible devices.',
#  'Besides, one never forgets a smartphone at home.',
#  'By the way, 33% of individuals worldwide use Todoist to handle their daily duties.',
#  'It is also possible to use the wall, online or mobile calendars.',
#  'One can mark important meetings and tasks there.',
#  'A system will send reminders, and a person will not forget about the upcoming event.',
#  'Finally, one should plan everything in advance.',
#  'It is a bad idea to start a day with a mess in one’s head.',
#  'Psychologists recommend scheduling in the evening to have a set-up mind in the morning.\n\n',
#  'An extra tip for beginners might be sharing duties and avoiding extra work.',
#  'For example, a person must make a team project.',
#  'All members should take equal responsibilities to guarantee their on-time performance.',
#  'If a friend asks an exhausted student to help, it will be better to excuse and refuse extra tasks.',
#  'Otherwise, a friend will succeed while a student will fail.\n\n',
#  'The above-mentioned facts and tips highlight the importance of good time management.',
#  'When people are not constantly in a hurry, they cope with many tasks and feel self-confident.',
#  'They are not afraid of the coming day that brings more responsibilities and duties.',
#  'Such people know how to turn a minute into a successful life investment.',
#  'Perfect time managers are not lazy.',
#  'They are productive and full of energy.',
#  'Leading organizations and companies desire to get such individuals in their teams to boost overall productivity.',
#  'Proper scheduling lets people be perfect leaders, team builders, assistants, and performers.',
#  'As William Shakespear once said, “Better to be three hours to noon, than a minute too late”.']

# %%
sent_score={}
for sent in sent_token:
    for word in sent.split():
        if word.lower() in word_freq.keys():
            if sent not in sent_score.keys():
                sent_score[sent]=word_freq[word]
            else:
                sent_score[sent]+=word_freq[word]
        print(word)
# Out:
# According
# to
# Tech
# Jury,
# despite
# a
# number
# of
# cool
# apps
# and
# tips
# for
# successful
# time
# management,
# only
# 17%
# of
# people
# track
# their
# time.
# 50%
# of
# people
# have
# never
# thought
# about
# time
# waste,
# even
# though
# they
# are
# always
# late
# and
# running
# out
# of
# time.
# Time
# management
# is
# a
# skill.
# It
# helps
# people
# handle
# their
# daily
# duties
# without
# burnout
# and
# severe
# exhaustion.
# The
# N.I.L.C.
# includes
# time
# management
# on
# the
# list
# of
# top
# ten
# demanded
# soft
# skills
# that
# employees
# require
# in
# 2022.
# Why
# is
# it
# so
# important
# to
# manage
# one’s
# time
# correctly?
# Stephen
# Covey
# once
# said,
# “The
# key
# is
# not
# spending
# time,
# but
# in
# investing
# it”.
# It
# means
# that
# proper
# timing
# guarantees
# a
# person’s
# success
# in
# many
# life
# areas.
# Career
# Trend
# names
# three
# negative
# aspects
# that
# occur
# when
# a
# person
# is
# not
# able
# to
# follow
# a
# schedule
# and
# be
# flexible.
# First
# off,
# one
# risks
# delaying
# the
# task
# performance
# all
# the
# time.
# People
# who
# got
# used
# to
# procrastination
# start
# doing
# assignments
# and
# duties
# at
# the
# very
# last
# moment.
# As
# a
# result,
# they
# sacrifice
# quality
# for
# the
# sake
# of
# deadlines.
# Moreover,
# procrastination
# is
# a
# perfect
# killer
# of
# vital
# energy
# and
# productiveness
# that
# are
# so
# essential
# in
# the
# XXI
# century.
# The
# second
# aspect
# is
# the
# development
# of
# a
# chronic
# late-coming
# habit.
# How
# can
# one
# come
# somewhere
# on
# time
# if
# a
# person
# cannot
# plan
# activities?
# Besides,
# late-coming
# and
# procrastination
# lead
# to
# the
# third
# negative
# aspect.
# It
# is
# a
# daily
# overload
# that
# results
# in
# burnout.
# When
# nothing
# is
# well-planned,
# people
# always
# get
# busy
# with
# something,
# go
# to
# bed
# late,
# and
# cannot
# relax.
# The
# pressure
# of
# undone
# tasks
# prevents
# them
# from
# normal
# sleep
# and
# rest.
# As
# a
# result,
# they
# acquire
# panic
# attacks,
# anxiety,
# sleep
# disorders,
# apathy,
# or
# depression.
# Mindtools
# introduces
# five
# benefits
# that
# people
# face
# when
# managing
# their
# day
# successfully.
# To
# begin
# with,
# such
# people
# are
# known
# as
# productive
# and
# effective
# in
# what
# they
# do.
# Employers
# adore
# such
# individuals
# because
# they
# handle
# many
# tasks
# faster
# than
# other
# employees.
# Secondly,
# ideal
# time
# managers
# almost
# never
# feel
# stressed
# at
# work.
# They
# know
# what
# they
# have
# to
# do
# and
# how
# much
# time
# they
# require
# for
# that.
# Third,
# scheduling
# is
# the
# best
# promoter.
# For
# example,
# if
# a
# student
# has
# free
# time
# after
# having
# done
# academic
# homework,
# it
# will
# be
# possible
# to
# broaden
# one’s
# look.
# Such
# a
# student
# can
# read
# books
# to
# enlarge
# personal
# vocabulary,
# practice
# in
# report
# or
# article
# writing,
# visit
# different
# places,
# and
# meet
# new
# people
# for
# networking.
# All
# these
# things
# lead
# to
# the
# next
# benefit
# which
# is
# a
# positive
# reputation.
# Motivated
# individuals
# with
# perfect
# timing
# skills
# usually
# become
# a
# model
# for
# following.
# Finally,
# perfect
# time
# managers
# have
# more
# chances
# to
# succeed
# in
# life
# than
# time
# wasters.
# Those
# who
# control
# their
# time
# can
# control
# and
# supervise
# others.
# What
# can
# a
# person
# do
# to
# learn
# proper
# scheduling?
# Professionals
# give
# seven
# tips
# that
# can
# help
# everyone
# get
# more
# control
# over
# time.
# The
# first
# one
# is
# to
# set
# goals.
# Motivation
# is
# an
# ignition
# key.
# Moreover,
# the
# goal
# is
# to
# be
# achievable.
# If
# a
# person
# is
# bad
# at
# Geometry
# and
# the
# creation
# of
# new
# things,
# it
# is
# better
# not
# to
# dream
# about
# becoming
# a
# top
# designer.
# The
# next
# task
# is
# to
# learn
# prioritizing
# concepts.
# People
# often
# do
# tasks
# that
# can
# be
# done
# later
# but
# delay
# duties
# that
# should
# be
# done
# here
# and
# right
# now.
# Moreover,
# they
# often
# neglect
# tasks
# that
# are
# long-perspective.
# For
# example,
# a
# person
# needs
# to
# master
# a
# second
# language
# to
# get
# the
# desired
# occupation.
# She
# does
# other
# tasks
# but
# forgets
# to
# memorize
# new
# words
# and
# practice
# daily.
# As
# a
# result,
# she
# will
# not
# get
# the
# job
# because
# language
# mastering
# demands
# more
# than
# one
# day.
# The
# next
# recommendation
# is
# to
# set
# time
# frames
# for
# each
# task
# and
# try
# not
# to
# change
# them.
# When
# a
# person
# sees
# the
# approaching
# deadline,
# he
# speeds
# up
# a
# bit
# and
# stops
# delaying
# duties.
# Another
# essential
# thing
# is
# to
# have
# rest.
# Brains
# and
# human
# bodies,
# in
# general,
# cannot
# function
# well
# when
# being
# exhausted.
# Everybody
# knows
# that
# 20
# minutes
# of
# noon
# sleep
# restores
# vital
# energy
# that
# helps
# to
# handle
# tasks
# in
# the
# second
# half
# of
# the
# day.
# Except
# for
# bedtime,
# one
# needs
# to
# enjoy
# a
# hobby
# or
# a
# pleasant
# activity.
# The
# best
# method
# to
# stay
# on
# alert
# is
# to
# have
# a
# notebook
# or
# install
# an
# app
# such
# as
# Todoist,
# TimeTree,
# etc.
# A
# benefit
# of
# a
# notebook
# is
# that
# a
# person
# deals
# only
# with
# scheduling
# and
# jotting
# down
# without
# being
# distracted
# by
# messages
# and
# notifications.
# The
# benefits
# of
# apps
# are
# their
# notification
# systems
# and
# compact
# seizes
# of
# compatible
# devices.
# Besides,
# one
# never
# forgets
# a
# smartphone
# at
# home.
# By
# the
# way,
# 33%
# of
# individuals
# worldwide
# use
# Todoist
# to
# handle
# their
# daily
# duties.
# It
# is
# also
# possible
# to
# use
# the
# wall,
# online
# or
# mobile
# calendars.
# One
# can
# mark
# important
# meetings
# and
# tasks
# there.
# A
# system
# will
# send
# reminders,
# and
# a
# person
# will
# not
# forget
# about
# the
# upcoming
# event.
# Finally,
# one
# should
# plan
# everything
# in
# advance.
# It
# is
# a
# bad
# idea
# to
# start
# a
# day
# with
# a
# mess
# in
# one’s
# head.
# Psychologists
# recommend
# scheduling
# in
# the
# evening
# to
# have
# a
# set-up
# mind
# in
# the
# morning.
# An
# extra
# tip
# for
# beginners
# might
# be
# sharing
# duties
# and
# avoiding
# extra
# work.
# For
# example,
# a
# person
# must
# make
# a
# team
# project.
# All
# members
# should
# take
# equal
# responsibilities
# to
# guarantee
# their
# on-time
# performance.
# If
# a
# friend
# asks
# an
# exhausted
# student
# to
# help,
# it
# will
# be
# better
# to
# excuse
# and
# refuse
# extra
# tasks.
# Otherwise,
# a
# friend
# will
# succeed
# while
# a
# student
# will
# fail.
# The
# above-mentioned
# facts
# and
# tips
# highlight
# the
# importance
# of
# good
# time
# management.
# When
# people
# are
# not
# constantly
# in
# a
# hurry,
# they
# cope
# with
# many
# tasks
# and
# feel
# self-confident.
# They
# are
# not
# afraid
# of
# the
# coming
# day
# that
# brings
# more
# responsibilities
# and
# duties.
# Such
# people
# know
# how
# to
# turn
# a
# minute
# into
# a
# successful
# life
# investment.
# Perfect
# time
# managers
# are
# not
# lazy.
# They
# are
# productive
# and
# full
# of
# energy.
# Leading
# organizations
# and
# companies
# desire
# to
# get
# such
# individuals
# in
# their
# teams
# to
# boost
# overall
# productivity.
# Proper
# scheduling
# lets
# people
# be
# perfect
# leaders,
# team
# builders,
# assistants,
# and
# performers.
# As
# William
# Shakespear
# once
# said,
# “Better
# to
# be
# three
# hours
# to
# noon,
# than
# a
# minute
# too
# late”.

# %%
sent_score
# Out:
# {'According to Tech Jury, despite a number of cool apps and tips for successful time management, only 17% of people track their time.': 2.095238095238095,
#  '50% of people have never thought about time waste, even though they are always late and running out of time.': 1.9047619047619049,
#  'Time management is a skill.': 0.19047619047619047,
#  'It helps people handle their daily duties without burnout and severe exhaustion.': 1.5238095238095235,
#  'The N.I.L.C. includes time management on the list of top ten demanded soft skills that employees require in 2022.': 1.666666666666667,
#  'Why is it so important to manage one’s time correctly?': 1.1428571428571428,
#  'Stephen Covey once said, “The key is not spending time, but in investing it”.': 0.19047619047619047,
#  'It means that proper timing guarantees a person’s success in many life areas.\n\n': 0.5238095238095237,
#  'Career Trend names three negative aspects that occur when a person is not able to follow a schedule and be flexible.': 0.8571428571428572,
#  'First off, one risks delaying the task performance all the time.': 0.38095238095238093,
#  'People who got used to procrastination start doing assignments and duties at the very last moment.': 0.6666666666666666,
#  'As a result, they sacrifice quality for the sake of deadlines.': 0.14285714285714285,
#  'Moreover, procrastination is a perfect killer of vital energy and productiveness that are so essential in the XXI century.': 0.8095238095238094,
#  'The second aspect is the development of a chronic late-coming habit.': 0.3333333333333333,
#  'How can one come somewhere on time if a person cannot plan activities?': 1.619047619047619,
#  'Besides, late-coming and procrastination lead to the third negative aspect.': 0.3333333333333333,
#  'It is a daily overload that results in burnout.': 0.2857142857142857,
#  'When nothing is well-planned, people always get busy with something, go to bed late, and cannot relax.': 0.6666666666666667,
#  'The pressure of undone tasks prevents them from normal sleep and rest.': 0.7619047619047619,
#  'As a result, they acquire panic attacks, anxiety, sleep disorders, apathy, or depression.\n\n': 0.23809523809523808,
#  'Mindtools introduces five benefits that people face when managing their day successfully.': 1.0476190476190477,
#  'To begin with, such people are known as productive and effective in what they do.': 0.8095238095238095,
#  'Employers adore such individuals because they handle many tasks faster than other employees.': 0.9047619047619047,
#  'Secondly, ideal time managers almost never feel stressed at work.': 1.3333333333333333,
#  'They know what they have to do and how much time they require for that.': 1.1904761904761907,
#  'Third, scheduling is the best promoter.': 0.3333333333333333,
#  'For example, if a student has free time after having done academic homework, it will be possible to broaden one’s look.': 1.4761904761904765,
#  'Such a student can read books to enlarge personal vocabulary, practice in report or article writing, visit different places, and meet new people for networking.': 1.4285714285714286,
#  'All these things lead to the next benefit which is a positive reputation.': 0.3333333333333333,
#  'Motivated individuals with perfect timing skills usually become a model for following.': 0.7142857142857142,
#  'Finally, perfect time managers have more chances to succeed in life than time wasters.': 2.6666666666666665,
#  'Those who control their time can control and supervise others.\n\n': 1.3333333333333333,
#  'What can a person do to learn proper scheduling?': 0.7142857142857142,
#  'Professionals give seven tips that can help everyone get more control over time.': 0.42857142857142855,
#  'The first one is to set goals.': 0.14285714285714285,
#  'Motivation is an ignition key.': 0.047619047619047616,
#  'Moreover, the goal is to be achievable.': 0.047619047619047616,
#  'If a person is bad at Geometry and the creation of new things, it is better not to dream about becoming a top designer.': 0.9523809523809523,
#  'The next task is to learn prioritizing concepts.': 0.2857142857142857,
#  'People often do tasks that can be done later but delay duties that should be done here and right now.': 0.9047619047619047,
#  'Moreover, they often neglect tasks that are long-perspective.': 0.47619047619047616,
#  'For example, a person needs to master a second language to get the desired occupation.': 0.9047619047619047,
#  'She does other tasks but forgets to memorize new words and practice daily.': 0.8571428571428571,
#  'As a result, she will not get the job because language mastering demands more than one day.': 0.23809523809523808,
#  'The next recommendation is to set time frames for each task and try not to change them.': 1.4761904761904763,
#  'When a person sees the approaching deadline, he speeds up a bit and stops delaying duties.': 0.8095238095238096,
#  'Another essential thing is to have rest.': 0.14285714285714285,
#  'Brains and human bodies, in general, cannot function well when being exhausted.': 0.09523809523809523,
#  'Everybody knows that 20 minutes of noon sleep restores vital energy that helps to handle tasks in the second half of the day.': 1.5714285714285712,
#  'Except for bedtime, one needs to enjoy a hobby or a pleasant activity.\n\n': 0.23809523809523808,
#  'The best method to stay on alert is to have a notebook or install an app such as Todoist, TimeTree, etc.': 0.42857142857142855,
#  'A benefit of a notebook is that a person deals only with scheduling and jotting down without being distracted by messages and notifications.': 1.0952380952380953,
#  'The benefits of apps are their notification systems and compact seizes of compatible devices.': 0.42857142857142855,
#  'Besides, one never forgets a smartphone at home.': 0.14285714285714285,
#  'By the way, 33% of individuals worldwide use Todoist to handle their daily duties.': 0.7142857142857142,
#  'It is also possible to use the wall, online or mobile calendars.': 0.2857142857142857,
#  'One can mark important meetings and tasks there.': 0.6190476190476191,
#  'A system will send reminders, and a person will not forget about the upcoming event.': 0.6666666666666667,
#  'Finally, one should plan everything in advance.': 0.09523809523809523,
#  'It is a bad idea to start a day with a mess in one’s head.': 0.5238095238095237,
#  'Psychologists recommend scheduling in the evening to have a set-up mind in the morning.\n\n': 0.38095238095238093,
#  'An extra tip for beginners might be sharing duties and avoiding extra work.': 0.8095238095238095,
#  'For example, a person must make a team project.': 0.5714285714285714,
#  'All members should take equal responsibilities to guarantee their on-time performance.': 0.23809523809523808,
#  'If a friend asks an exhausted student to help, it will be better to excuse and refuse extra tasks.': 0.8095238095238095,
#  'Otherwise, a friend will succeed while a student will fail.\n\n': 0.38095238095238093,
#  'The above-mentioned facts and tips highlight the importance of good time management.': 1.3333333333333333,
#  'When people are not constantly in a hurry, they cope with many tasks and feel self-confident.': 1.1904761904761907,
#  'They are not afraid of the coming day that brings more responsibilities and duties.': 0.5714285714285714,
#  'Such people know how to turn a minute into a successful life investment.': 1.0476190476190474,
#  'Perfect time managers are not lazy.': 1.1428571428571428,
#  'They are productive and full of energy.': 0.09523809523809523,
#  'Leading organizations and companies desire to get such individuals in their teams to boost overall productivity.': 0.47619047619047616,
#  'Proper scheduling lets people be perfect leaders, team builders, assistants, and performers.': 1.1904761904761902,
#  'As William Shakespear once said, “Better to be three hours to noon, than a minute too late”.': 0.14285714285714285}

# %%
import pandas as pd

# %%
pd.DataFrame(list(sent_score.items()),columns=['Sentence','Score'])
# Out:
#                                              Sentence     Score
# 0   According to Tech Jury, despite a number of co...  2.095238
# 1   50% of people have never thought about time wa...  1.904762
# 2                         Time management is a skill.  0.190476
# 3   It helps people handle their daily duties with...  1.523810
# 4   The N.I.L.C. includes time management on the l...  1.666667
# ..                                                ...       ...
# 70                Perfect time managers are not lazy.  1.142857
# 71            They are productive and full of energy.  0.095238
# 72  Leading organizations and companies desire to ...  0.476190
# 73  Proper scheduling lets people be perfect leade...  1.190476
# 74  As William Shakespear once said, “Better to be...  0.142857
#
# [75 rows x 2 columns]

# %%
from heapq import nlargest

# %%
num_sentences=3
n=nlargest(num_sentences,sent_score,key=sent_score.get)

# %%
" ".join(n)
# Out:
# 'Finally, perfect time managers have more chances to succeed in life than time wasters. According to Tech Jury, despite a number of cool apps and tips for successful time management, only 17% of people track their time. 50% of people have never thought about time waste, even though they are always late and running out of time.'

# %%
from transformers import pipeline

# %%
summarizer=pipeline("summarization",model='t5-base',tokenizer='t5-base',framework='pt')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]

# %%
summary=summarizer(text,max_length=100,min_length=10,do_sample=False)

# %%
summary
# Out:
# [{'summary_text': 'according to Tech Jury, only 17% of people track their time . 50% of people have never thought about time waste, even though they are always late . professionals give seven tips that can help everyone get more control .'}]

# %%
print(summary[0]['summary_text'])
# Out:
# according to Tech Jury, only 17% of people track their time . 50% of people have never thought about time waste, even though they are always late . professionals give seven tips that can help everyone get more control .
